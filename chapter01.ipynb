# %% [markdown]
# ### 00. 文字列の逆順

# %%
x = 'stressed'
x = x[::-1]
x
# Out:
# 'desserts'

# %% [markdown]
# ### 01. 「パタトクカシーー」

# %%
x = 'パタトクカシー'
x = x[::2]
x
# Out:
# 'パトカー'

# %% [markdown]
# ### 02. 「パトカー」＋「タクシー」＝「パタトクカシーー」

# %%
from itertools import zip_longest

# %%
x1 = 'パトカー'
x2 = 'タクシー'
x = [
    char
    for two_chars in zip_longest(x1, x2, fillvalue = '')
    for char in two_chars
]
x = ''.join(x)
x
# Out:
# 'パタトクカシーー'

# %% [markdown]
# ### 03. 円周率

# %%
import re

# %%
x = 'Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics.'
x = re.sub(r'[^\w\s]', '', x)
x = x.split(' ')
x = [len(word) for word in x]
x
# Out:
# [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5, 8, 9, 7, 9]

# %% [markdown]
# ## 04. 元素記号

# %%
x = 'Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can.'
x = x.split(' ')
idx = {1, 5, 6, 7, 8, 9, 15, 16, 19}
d1 = [(num + 1, word[:1]) for num, word in enumerate(x) if num + 1 in idx]
d2 = [(num + 1, word[:2]) for num, word in enumerate(x) if num + 1 not in idx]
dct = {name:num for num, name in d1 + d2}
dct
# Out:
# {'H': 1,
#  'B': 5,
#  'C': 6,
#  'N': 7,
#  'O': 8,
#  'F': 9,
#  'P': 15,
#  'S': 16,
#  'K': 19,
#  'He': 2,
#  'Li': 3,
#  'Be': 4,
#  'Ne': 10,
#  'Na': 11,
#  'Mi': 12,
#  'Al': 13,
#  'Si': 14,
#  'Cl': 17,
#  'Ar': 18,
#  'Ca': 20}

# %% [markdown]
# ### 05. n-gram

# %%
def ngram(n, lst):
    return list(zip(*[lst[i:] for i in range(n)]))

# %%
chars = 'I am an NLPer'
char_bi_gram = ngram(2, chars)

words = chars.split(' ')
word_bi_gram = ngram(2, words)

print('文字 bi-gram', char_bi_gram)
print('単語 bi-gram', word_bi_gram)
# Out:
# 文字 bi-gram [('I', ' '), (' ', 'a'), ('a', 'm'), ('m', ' '), (' ', 'a'), ('a', 'n'), ('n', ' '), (' ', 'N'), ('N', 'L'), ('L', 'P'), ('P', 'e'), ('e', 'r')]
# 単語 bi-gram [('I', 'am'), ('am', 'an'), ('an', 'NLPer')]

# %%
from functools import partial

# %%
bigram = partial(ngram, 2)
bigram(chars)
# Out:
# [('I', ' '),
#  (' ', 'a'),
#  ('a', 'm'),
#  ('m', ' '),
#  (' ', 'a'),
#  ('a', 'n'),
#  ('n', ' '),
#  (' ', 'N'),
#  ('N', 'L'),
#  ('L', 'P'),
#  ('P', 'e'),
#  ('e', 'r')]

# %% [markdown]
# ### 06. 集合

# %%
str1 = 'paraparaparadise'
str2 = 'paragraph'
X = set(ngram(2, str1))
Y = set(ngram(2, str2))
print('積集合', X & Y)
print('差集合', X - Y)
print('se in X?', ('s', 'e') in X)
print('se in Y?', ('s', 'e') in Y)
# Out:
# 積集合 {('a', 'p'), ('r', 'a'), ('p', 'a'), ('a', 'r')}
# 差集合 {('i', 's'), ('d', 'i'), ('s', 'e'), ('a', 'd')}
# se in X? True
# se in Y? False

# %% [markdown]
# ### 07. テンプレートによる文生成

# %%
def temperature(x, y, z):
    return '{}時の{}は{}'.format(x, y, z)

# %%
temperature(12, '気温', 22.4)
# Out:
# '12時の気温は22.4'

# %% [markdown]
# ### 08. 暗号文

# %%
def cipher(xs):
    xs = [chr(219 - ord(x)) if x.islower() else x for x in xs]
    return ''.join(xs)

# %%
x = 'The quick brown fox jumps over the lazy dog. 1234567890'
print('平文', x)
x = cipher(x)
print('暗号文', x)
x = cipher(x)
print('復号文', x)
# Out:
# 平文 The quick brown fox jumps over the lazy dog. 1234567890
# 暗号文 Tsv jfrxp yildm ulc qfnkh levi gsv ozab wlt. 1234567890
# 復号文 The quick brown fox jumps over the lazy dog. 1234567890

# %% [markdown]
# ### 09. Typoglycemia

# %%
import random as rd

# %%
def typoglycemia(x):
    if len(x) <= 4:
        return x
    mid = list(x[1:-1])
    rd.shuffle(mid)
    mid = ''.join(mid)
    return x[0] + mid + x[-1]

# %%
x = "I couldn't believe that I could actually understand what I was reading : the phenomenal power of the human mind ."
x = x.split(' ')
x = [typoglycemia(word) for word in x]
x = ' '.join(x)
x
# Out:
# "I cln'udot beeivle that I cuold aulalcty uredatnnsd what I was rednaig : the pnoeaenmhl peowr of the hmuan mind ."
